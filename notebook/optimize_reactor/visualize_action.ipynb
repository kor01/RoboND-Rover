# %%
from matplotlib import pyplot as plt
import numpy as np
from replay_analysis import load_replay_from_csv

# %%
frames = np.load('/home/pu/dataset/wall_crawler_train/frames.npy')
throttle, brake, steer, switch = np.load('/home/pu/dataset/wall_crawler_train/labels.npy')

# %%
experience = load_replay_from_csv('/home/pu/dataset/wall_crawler/robot_log.csv')

# %%
index = 191
print('steer is', steer[index])
plt.imshow(frames[index])
plt.show()
# Out:
# steer is 112

# %%
index = 190
print('original steer is', experience.metrics['SteerAngle'][index])
plt.imshow(experience.frames[index])
plt.show()
# Out:
# original steer is -6.00693

# %%
brake = experience.metrics['Brake']

# %%
brake = brake[brake.nonzero()[0]]

# %%
steer = experience.metrics['SteerAngle']

# %%
steer[steer.nonzero()[0]][]
# Out:
# array([ 1.50322795,  3.74832296,  6.00736523, ...,  3.00807595,
#         3.76377201,  1.51660705], dtype=float32)
