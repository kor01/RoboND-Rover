# %%
import sys
import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

from replay_analysis import ExperienceRelay
from replay_analysis import filter_frames
from replay_analysis import get_debug_values
from replay_analysis import analysis_case
from replay_analysis import PerspectiveRender
from replay_analysis import GradientAnalysis
from replay_analysis import highlight_position
from replay_analysis import pitch_roll_deviation

from experiment_path import experiment
from rover_spec import GROUND_TRUTH_MAP

# %%
gradient_analyzer = GradientAnalysis(GROUND_TRUTH_MAP)
path = experiment('perception_optimize/zyx_rotated_perspective')
replay = ExperienceRelay(path=path)
render = PerspectiveRender(scale=1, resolution=60)

# %%
# singular drop = 0
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F77FB532160>

# %%
# singular drop = 1
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '1'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F178470>

# %%
# singular drop = 2
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '2'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F476F98>

# %%
# singular drop = 3
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '3'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F4000B8>

# %%
# singular drop = 4
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '4'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E550EB2B0>

# %%
# singular drop = 5
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '5'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F1AC278>

# %%
# singular drop = 6
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '6'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F348358>

# %%
# singular drop = 7
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '7'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4E0F39C550>

# %%
# singular drop = 8
replay.reset_config({'PERCEPTION': {'ZYXSingularDrop': '8'}})
replay.replay()
replay.frames[-1].map
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F4DD868B518>

# %% [markdown]
# the algorithm achieve the best fideility (64.3) without near singular drop
#
# achieve the best coverage/fidelity trade-off
#
# achieve
